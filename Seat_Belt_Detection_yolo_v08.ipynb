# %% [markdown]
# <a href="https://colab.research.google.com/github/HayaAbdullahM/Seat-Belt-Detection/blob/Yolov8/Seat_Belt_Detection_yolo_v08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Mar 26 19:13:59 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd() #provdie me the dirctory that i work on.
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/201.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="g45JUusQYcWYulQqZyjP")
project = rf.workspace("fay-regu8").project("seat_belt-iauiy")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=200 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.1.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
from IPython.display import Image

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=500)

# %%
Image(filename=f'/content/runs/detect/train2/val_batch2_pred.jpg', width=500)

# %%
from google.colab import files
files.download('yolov8n.pt')

# %%
# Zip the folder
# !zip -r run.zip /content/runs

# Download the zip file
files.download('run.zip')
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 32%)
#   adding: content/runs/detect/train2/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train2/args.yaml (deflated 51%)
#   adding: content/runs/detect/train2/results.csv (deflated 85%)
#   adding: content/runs/detect/train2/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train2/val_batch2_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 33%)
#   adding: content/runs/detect/train2/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train2/labels_correlogram.jpg (deflated 44%)
# ...
